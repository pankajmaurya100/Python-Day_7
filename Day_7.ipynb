# %% [markdown]
# Day_7
# Strings in python

# %%
a = 'hello'
print(a)
# Out:
# hello

# %%
b = "we are learning python and this is our 7 class"
print(b)
print(type(b))
# Out:
# we are learning python and this is our 7 class
# <class 'str'>

# %%
a = "hello students"
print(a[11])
# Out:
# n

# %%
a = "hello student"
print(a[9])
# Out:
# d

# %%
s = "hello student how are you"
print(s[0:5])
# Out:
# hello

# %%
s = "hello student how are you"
print(s[0:12])
# Out:
# hello studen

# %%
s = "hello student how are you"
print(s[0:18])
# Out:
# hello student how

# %%
s = "hello student how are you"
print(s[0:20:3])
# Out:
# hlsdtoa

# %%
s = "hello student how are you"
print(s[::-1])
# Out:
# uoy era woh tneduts olleh

# %%
a = "this is our day 7 python class"
print(len(a))
# Out:
# 30

# %%
b = "hello world"
print(b)
print(len(b))
# Out:
# hello world
# 11

# %%
a = "hello how are you"
print(a.upper())
# Out:
# HELLO HOW ARE YOU

# %%
a = "hello how are you"
print(a.upper())
# Out:
# HELLO HOW ARE YOU

# %%
a = "HELLO STUDENT HOW ARE YOU"
print(a.lower())
# Out:
# hello student how are you

# %%
a = "hello how are you"
print(a.replace("hello", "Mohit"))
# Out:
# Mohit how are you

# %%
b = "hello world"
print(b)
print(b.replace("world", "students"))
# Out:
# hello world
# hello students

# %%
a = "python is greate"
b = a.find("g")
print(b)
# Out:
# 10

# %%
a = "python is greate"
b = a.find("s")
print(b)
# Out:
# 8
